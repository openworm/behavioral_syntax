# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt


from behavioral_syntax.visualization.view_postures2 import view_postures

postures = '/Users/cyrilrocke/Documents/c_elegans/data/postures'

view_postures(postures)
